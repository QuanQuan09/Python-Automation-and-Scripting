# %%
print("Python Automation Bootcamp")
print("Today I begin learning automation.")
print("Future me will automate repetitive work.")
# Out:
# Python Automation Bootcamp
# Today I begin learning automation.
# Future me will automate repetitive work.
