# %%
# Finding My Current Folder

import os

print(os.getcwd())
# Out:
# /Users/laquandramissick/Python Automation and Scripting Bootcamp/Week 1 - Python as a Productivity Tool

# %%
# Listing Files in a Folder

import os

files = os.listdir()

print(files)
# Out:
# ['W1L2 - Working with Files.ipynb', 'W1L1.ipynb', 'server_log.txt', 'automation_notes.txt', '.ipynb_checkpoints', 'daily_report.txt', 'W1L3 - Working with Folders.ipynb']

# %%
# Loop Through the Files
# Instead of printing one big list:

import os

for file in os.listdir():
    print(file)
# Out:
# W1L2 - Working with Files.ipynb
# W1L1.ipynb
# server_log.txt
# automation_notes.txt
# .ipynb_checkpoints
# daily_report.txt
# W1L3 - Working with Folders.ipynb

# %%
# Creating a Folder named Reports

import os

os.mkdir("Reports")

# %%
# Check Before Creating - a better approach:

import os

if not os.path.exists("Reports"):
    os.mkdir("Reports")

# %%
# Does a File Exist?

import os
print(os.path.exists("server_log.txt"))
# Out:
# True

# %%
# Does a File Exist?

print(os.path.exists("pizza.txt"))
# Out:
# False

# %%
# First Folder Automation Script

import os

folder_name = "Daily_Reports"

if not os.path.exists(folder_name):
    os.mkdir(folder_name)
    print("Folder created!")
else:
    print("Folder already exists.")
# Out:
# Folder created!

# %%
# Mini Challenge 1

#print current working directory

import os

print(os.getcwd())
# Out:
# /Users/laquandramissick/Python Automation and Scripting Bootcamp/Week 1 - Python as a Productivity Tool

# %%
# Mini Challenge 2

# create for loop

for file in os.listdir():
    print(file)
# Out:
# W1L2 - Working with Files.ipynb
# W1L1.ipynb
# server_log.txt
# automation_notes.txt
# .ipynb_checkpoints
# Daily_Reports
# daily_report.txt
# W1L3 - Working with Folders.ipynb
# Reports

# %%
# Mini Challenge 3

# Create folder named Automation Practice; print "Folder already exists" if it already exists

import os

folder_name = "Automation_Practice"

if not os.path.exists(folder_name):
    os.mkdir(folder_name)
    print("Folder created!")

else:
    print("Folder already exists!")
# Out:
# Folder created!

# %%
# Mini Challenge 4

# check if these exist: server_log.txt; Automation_Practice; banana.txt

print(os.path.exists("server_log.txt"))
print(os.path.exists("Automation_Practice"))
print(os.path.exists("banana.txt"))
# Out:
# True
# True
# False

# %%
from pathlib import Path

print(Path.cwd())
# Out:
# /Users/laquandramissick/Python Automation and Scripting Bootcamp/Week 1 - Python as a Productivity Tool

# %%
# Mini Coding Exercise

import os

print(os.getcwd())

for file in os.listdir():
    print(file)
# Out:
# /Users/laquandramissick/Python Automation and Scripting Bootcamp/Week 1 - Python as a Productivity Tool
# W1L2 - Working with Files.ipynb
# W1L1.ipynb
# server_log.txt
# Automation_Practice
# automation_notes.txt
# .ipynb_checkpoints
# Daily_Reports
# daily_report.txt
# W1L3 - Working with Folders.ipynb
# Reports

# %%
# Mini Coding Exercise

import os

folder_name = "Python_Practice"

if not os.path.exists(folder_name):
    os.mkdir(folder_name)
    print("Folder Created!")

else:
    print("Folder Not Created!")
# Out:
# Folder Created!

# %%
import os

print(os.path.exists("server_log.txt"))
print(os.path.exists("Python_Practice"))
print(os.path.exists("Week1_Lesson3.ipynb"))
# Out:
# True
# True
# False
