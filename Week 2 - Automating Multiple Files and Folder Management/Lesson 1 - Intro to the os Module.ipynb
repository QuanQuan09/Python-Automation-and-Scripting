# %%
# Step 1 - Import os

import os

# %%
# Step 2 - Current Working Directory

import os

print(os.getcwd())
# Out:
# /Users/laquandramissick/Python Automation and Scripting Bootcamp/Week 2 - Automating Multiple Files and Folder Management

# %%
# Step 3 - List Everything Inside a Folder

import os

print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'Lesson 1 - Intro to the os Module.ipynb']

# %%
# Step 4 - Looping Through the Files

import os

for file in os.listdir():
    print(file)
# Out:
# .ipynb_checkpoints
# Lesson 1 - Intro to the os Module.ipynb

# %%
# Step 5 - Check if Something Exists

import os

print(os.path.exists("servers.csv"))
# Out:
# False

# %%
if os.path.exists("servers.csv"):
    print("Found!")
else:
    print("Missing file.")
# Out:
# Missing file.

# %%
# Step 6 - Create a Folder

import os

os.mkdir("reports")

# %%
# another approach

if not os.path.exists("reports"):
    os.mkdir("reports")

# %%
# Mini Example

import os

print("Current Folder:")
print(os.getcwd())

print()

print("Contents:")

for item in os.listdir():
    print(item)

if not os.path.exists("Reports"):
    os.mkdir("Reports")

print("\nReports folder is ready!")
# Out:
# Current Folder:
# /Users/laquandramissick/Python Automation and Scripting Bootcamp/Week 2 - Automating Multiple Files and Folder Management
#
# Contents:
# .ipynb_checkpoints
# Lesson 1 - Intro to the os Module.ipynb
# reports
#
# Reports folder is ready!
